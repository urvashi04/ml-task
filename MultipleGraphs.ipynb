# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('bank.csv')

# %%
df
# Out:
#       RowNumber  CustomerId         Surname  CreditScore Geography  Gender  \
# 0             1    15634602        Hargrave          619    France  Female
# 1             2    15647311            Hill          608     Spain  Female
# 2             3    15619304            Onio          502    France  Female
# 3             4    15701354            Boni          699    France  Female
# 4             5    15737888        Mitchell          850     Spain  Female
# 5             6    15574012             Chu          645     Spain    Male
# 6             7    15592531        Bartlett          822    France    Male
# 7             8    15656148          Obinna          376   Germany  Female
# 8             9    15792365              He          501    France    Male
# 9            10    15592389              H?          684    France    Male
# 10           11    15767821          Bearce          528    France    Male
# ...

# %%
x=df['Surname']

# %%
y=df['CreditScore']

# %%
plt.plot(x, y) 
plt.xlabel('x - axis') 
plt.ylabel('y - axis') 
plt.title('My first graph!') 
#plt.show()
# Out:
# Text(0.5, 1.0, 'My first graph!')

# %%
x1=df['Geography']

# %%
y1=df['Age']

# %%
plt.pie(y1,labels=x1,shadow=True)
plt.show()

# %%
df.groupby('Gender').size().plot('pie',shadow=True, label='Gender' ,autopct='%1.1f%%')

# %%
df.groupby('Geography').size().plot('pie', shadow=True,label='Geography' ,autopct='%1.1f%%')

# %%
df.groupby('Geography').size().plot('bar')

# %%
plt.stackplot(df.Gender,df.EstimatedSalary)
plt.xlabel('Gender')
plt.ylabel('EstimatedSalary')
# Out:
# Text(0, 0.5, 'EstimatedSalary')

# %%
plt.bar(df.Gender,df.EstimatedSalary)
plt.xlabel('Gender')
plt.ylabel('EstimatedSalary')
# Out:
# Text(0, 0.5, 'EstimatedSalary')

# %%
plt.scatter(x, y, label= "Surname", color= "green",  
            marker= "*", s=30)
